# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
image = Image.open('DATA/00-puppy.jpg')

# %%
type(image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
image.format
# Out:
# 'JPEG'

# %%
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(10, 7))
ax.imshow(image, cmap='gray')

# %%
dog = np.asarray(image)

# %%
dog.shape
# Out:
# (1300, 1950, 3)

# %%
dog_copy = dog.copy()

# %%
dog_copy[0].shape
# Out:
# (1950, 3)

# %%
dog_copy[:, :, 0].shape
# Out:
# (1300, 1950)

# %%
plt.imshow(dog_copy[:, :, 0])

# %%
plt.imshow(dog_copy[:, :, 0], cmap='gray')

# %%
plt.imshow(dog_copy[:, :, 1])

# %%
plt.imshow(dog_copy[:, :, 1], cmap='gray')

# %%
plt.imshow(dog_copy[:, :, 2])

# %%
plt.imshow(dog_copy[:, :, 2], cmap="gray")
